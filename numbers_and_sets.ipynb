# %% [markdown]
# Sure! Here are 20 examples of numbers and sets in Python:
#
# Numbers:
# 1. Calculate the sum of two numbers.
# 2. Find the absolute value of a number.
# 3. Calculate the square root of a number.
# 4. Convert a decimal number to binary.
# 5. Generate a random number between a specified range.
# 6. Check if a number is prime.
# 7. Round a floating-point number to a specified decimal place.
# 8. Calculate the factorial of a number.
# 9. Find the maximum and minimum values in a list of numbers.
# 10. Calculate the average of a list of numbers.
#
# Sets:
# 1. Create an empty set.
# 2. Add elements to a set.
# 3. Remove an element from a set.
# 4. Check if an element exists in a set.
# 5. Find the union of two sets.
# 6. Find the intersection of two sets.
# 7. Check if one set is a subset of another set.
# 8. Remove all elements from a set.
# 9. Find the difference between two sets.
# 10. Check if two sets are disjoint (have no common elements).
#
# These examples provide a variety of tasks involving numbers and sets in Python. They can serve as practice exercises to enhance your understanding and proficiency in working with numbers and sets in Python programming.

# %%
#Check if one set is a subset of another set.
set1={1,2,3,4,5,6}
set2={4,5}
if set2.issubset(set1):
 print("set2 issubset of set1")
else:
  print("set2 isnotsubset of set1")
# Out:
# set2 issubset of set1

# %%
#Find the intersection of two sets
set1={1,2,3,4,5}
set2={3,4,5,6,7}
intersection_set=set1.intersection(set2)
print(intersection_set)
# Out:
# {3, 4, 5}

# %%
#Find the union of two sets.
set1={1,2,3,4,5}
set2={3,4,5,6,7}
union_set=set1.union(set2)
print(union_set)
# Out:
# {1, 2, 3, 4, 5, 6, 7}

# %%
#Check if an element exists in a set
my_set={1,2,3,4,5,6}
#check if 3 exists in my_set
if 3 in my_set:
  print("3 exists in my set")
# Out:
# 3 exists in my set

# %%
#Remove an element from a set.
my_set={1,2,3,4,5}
my_set.remove(3)
print(my_set)
# Out:
# {1, 2, 4, 5}

# %%
#Add elements to a set.
my_set={1,2,3}
my_set.update([4,5])
print(my_set)
# Out:
# {1, 2, 3, 4, 5}

# %%
#Create an empty set.
empty_set={}
print(empty_set)
# Out:
# {}

# %%
#Find the absolute value of a number.
num=-123
absolute_value=abs(num)
print(absolute_value)
# Out:
# 123

# %%
#Calculate the sum of two numbers.
num1=(123)
num2=(456)
num3=num1+num2
print(num3)
# Out:
# 579
