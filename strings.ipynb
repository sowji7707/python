# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# https://www.programiz.com/python-programming/string

# %%
print("Hello world")
# Out:
# Hello world

# %% [markdown]
# Operating Systems:
# Linux
# Mac
# Windows

# %%
# !python --version
# Out:
# Python 3.10.12

# %%
my_name = 'siri'
my_name =  "siri"
my_name = """ssiri Reddy1234"""
my_nmae="1234"

# %%
my_name[5:10:2]
# Out:
# 'Rdy'

# %%
my_name[-5:]
# Out:
# 'Reddy'

# %%
my_name[::-2]
# Out:
# 'ydRii'

# %%
my_name[::1]
# Out:
# 'ssiri Reddy '

# %%
my_name
# Out:
# 'siri Reddy'

# %%
type(my_name)
# Out:
# str

# %%
import pandas as pd
df=pd.DataFrame(dir(my_name))

# %%
str1 = "Hemanth"
str2= "Reddy"
str1 = str1 + str2
str1
# Out:
# 'HemanthReddy'

# %%
type(str1)
# Out:
# str

# %%
print(f"upper case: {my_name.upper()}")
print(f"lower case: {my_name.lower()}")
print(f"Captiliaze case: {my_name.capitalize()}")
# Out:
# upper case: SIRI REDDY
# lower case: siri reddy
# Captiliaze case: Siri reddy

# %%
print(f"Captiliaze case: {my_name.title()}")
# Out:
# Captiliaze case: Ssiri Reddy

# %%
my_name = "   hemanth   reddy "

# %%
print(f"remove case: {my_name.strip()}") #rstrip(), lstrip()
# Out:
# remove case: hemanth   reddy

# %%
print(my_name.replace('man', 'mango'))
# Out:
#    hemangoth   reddy

# %%
my_name.split('r')
# Out:
# ['ssi', 'i Reddy ']

# %% [markdown]
# String Concatenation: Take two or more strings and concatenate them to form a single string.
#
# String Length: Find the length of a given string.
#
# String Slicing: Extract a specific portion of a string using slicing indices.
#
# String Case Conversion: Convert a string to uppercase or lowercase.
#
# String Reversal: Reverse a given string.
#
#  nString Count: Count the occurrences of a specific substring within a string.
#
# String Replace: Replace a substring with another substring within a string.
#
# String Split: Split a string into a list of substrings based on a delimiter.
#
# String Join: Join a list of strings into a single string using a specified separator.
#
# String Formatting: Format a string by replacing placeholders with variable values.

# %%
 str1= "sowjanya"
 str2= "reddy"
 str1=str1+str2
 str1
# Out:
# 'sowjanyareddy'

# %%
my_string="sowjanya jonnala"
length=len(my_string)
print(length)
# Out:
# 16

# %%
my_string="sowjanya jonnala"
substring=my_string[9:16]
print(substring)
# Out:
# jonnala

# %%
my_name="sowjanya jonnala"
uppercase_name=my_name.upper()
lowercase_name=my_name.lower()
print(uppercase_name)
print(lowercase_name)
# Out:
# SOWJANYA JONNALA
# sowjanya jonnala

# %%
my_name="sowjanya jonnala"
reversed_name=my_name[::-1]
print(reversed_name)
# Out:
# alannoj aynajwos

# %%
my_name="sowji sowji sowji jonnala"
subname="sowji"
count=my_name.count(subname)
print(count)
# Out:
# 3

# %%
my_name="sowjanya jonnala"
new_name=my_name.replace("jonnala","meruva")
print(new_name)
# Out:
# sowjanya meruva

# %%
lstrip()

# %% [markdown]
# Certainly! Here are 20 exercises on strings:
#
# 1. Create an empty string.
# 2. Create a string with a specific message.
# 3. Access and print the first character of a string.
# 4. Concatenate two strings.
# 5. Find the length of a string.
# 6. Convert a string to uppercase.
# 7. Convert a string to lowercase.
# 8. Check if a specific word is present in a string.
# 9. Replace a specific word in a string with another word.
# 10. Remove all whitespace characters from a string.
# 11. Split a string into a list of words.
# 12. Join a list of words into a single string.
# 13. Check if a string starts with a specific prefix.
# 14. Check if a string ends with a specific suffix.
# 15. Count the number of occurrences of a specific character in a string.
# 16. Reverse the order of characters in a string.
# 17. Extract a substring from a string.
# 18. Check if a string is alphanumeric.
# 19. Check if a string is numeric.
# 20. Convert a string representation of a number to an actual numeric value.
#
# These exercises cover various string operations and concepts in Python. They can help you practice manipulating strings and reinforce your understanding of string handling in Python.

# %%
# convert string to numeric
string_num="12345"
numeric_value=int(string_num)
print(numeric_value)
type(numeric_value)
# Out:
# 12345
# int

# %%
dir(string_num)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'removeprefix',
#  'removesuffix',
#  'replace',
# ...

# %%
empty_string=""

# %%
print("wa" not in "sowjnaya")
# Out:
# True

# %%
list of numbers=[1,2,3,4,5]
numeric_value=int(list of numbers)
print(numeric_value)
# Out:
#   File "<ipython-input-3-fec19bd8ac46>", line 1
#     list of numbers=[1,2,3,4,5]
#          ^
# SyntaxError: invalid syntax

# %%
number_list=["1","2"]
number_string="".join(number_list)
numeric_value=int(number_string)
print(numeric_value)
# Out:
# 12

# %%
my_string="123435"
is_numeric=my_string.isdigit()
print(is_numeric)
# Out:
# True

# %%
my_list=[1,2,3,4,5]
is_numeric=all(isinstance(element, (int,float))for element in my_list)
print(is_numeric)
# Out:
# True

# %%
empty_list=[]

# %%
my_string="hello"
first_character=my_string[0]
print(first_character)
# Out:
# h

# %%
my_list=[1,2,3,4,5]
first_number=my_list[0]
print(first_number)
# Out:
# 1

# %%
string1="hello"
string2="sowjanya"
string3=string1+string2
print(string3)
# Out:
# hellosowjanya

# %%
list1=[1,2,3,4]
list2=[5,6,7,8]
list3=list1+list2
print(list1+list2)
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8]

# %%
my_string="sowjanya jonnala"
len_string=my_string[1::]
print(len_string)
# Out:
# owjanya jonnala

# %%
my_string="sowjanya jonnala"
length=len(my_string)
print(length)
# Out:
# 16

# %%
my_list=[1,3,4,5,6,7,8,9]
length=len(my_list)
print(length)
# Out:
# 8

# %%
my_string="sowjanya jonnala"
uppercase_string=my_string.upper()
lowercase_string=my_string.lower()
print(uppercase_string,lowercase_string)
# Out:
# SOWJANYA JONNALA sowjanya jonnala

# %%
my_list=['apple','banana']
def convert_to_uppercase(input_list):
  out_list = []
  for item in input_list:
    if isinstance(item, str):
      out_list.append(item.upper())
    else:
      out_list.append(item)
  return out_list

uppercase_list=convert_to_uppercase(my_list)
lowercase_list=covert_to_lowercase(my_list)
print(uppercase_list,lowercase_list)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-5503c208935e> in <cell line: 2>()
#       1 my_list=['apple','banana']
# ----> 2 uppercase_list=convert_to_uppercase(my_list)
#       3 lowercase_list=covert_to_lowercase(my_list)
#       4 print(uppercase_list,lowercase_list)
#
# NameError: name 'convert_to_uppercase' is not defined

# %%
my_string="sowjanya jonnala"
reversed_string=my_string[::-1]
print(reversed_string)
# Out:
# alannoj aynajwos

# %%
my_list=[1,2,3,4,5]
reversed_list=my_list[::-1]
print(reversed_list)
# Out:
# [5, 4, 3, 2, 1]

# %%
my_name="SOWJI,SOWJI,JONNALA"
subname="SOWJI"
count=my_name.count(subname)
print(count)
# Out:
# 2

# %%
my_list=[1,1,1,1,1,1,1,2,3,4]
sublist=1
count=my_list.count(1)
print(count)
# Out:
# 7

# %%
my_name="sowjanya jonnla"
new_name=my_name.replace("jonnla","meruva")
print(new_name)
# Out:
# sowjanya meruva

# %%
my_list=[1,1,1,1,2,3,4,5]
new_list=["one" if num==1 else num for num in my_list]
print(new_list)
# Out:
# ['one', 'one', 'one', 'one', 2, 3, 4, 5]

# %%
my_name="hello",

# %%
type(my_name)
# Out:
# tuple

# %%
dir(my_name)
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'count',
#  'index']

# %%
n = [1,2,3]
n.replace(1, 3)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-2-01c92a2e5486> in <cell line: 2>()
#       1 n = [1,2,3]
# ----> 2 n.replace(1, 3)
#
# AttributeError: 'list' object has no attribute 'replace'

# %%
my_string="sowji"

# %%
type(my_string)
# Out:
# str

# %%
dir(my_string)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'removeprefix',
#  'removesuffix',
#  'replace',
# ...

# %%
my_list = [1,2, 3,"hello"]

# %%
a = 1
a.upper()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-a902953f0571> in <cell line: 2>()
#       1 a = 1
# ----> 2 a.upper()
#
# AttributeError: 'int' object has no attribute 'upper'

# %%
dir(my_string)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'removeprefix',
#  'removesuffix',
#  'replace',
# ...

# %%
dir(1)
# Out:
# ['__abs__',
#  '__add__',
#  '__and__',
#  '__bool__',
#  '__ceil__',
#  '__class__',
#  '__delattr__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__float__',
#  '__floor__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__index__',
#  '__init__',
#  '__init_subclass__',
#  '__int__',
#  '__invert__',
#  '__le__',
#  '__lshift__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
#  '__or__',
#  '__pos__',
#  '__pow__',
#  '__radd__',
#  '__rand__',
#  '__rdivmod__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rfloordiv__',
#  '__rlshift__',
#  '__rmod__',
#  '__rmul__',
#  '__ror__',
#  '__round__',
#  '__rpow__',
#  '__rrshift__',
#  '__rshift__',
#  '__rsub__',
#  '__rtruediv__',
#  '__rxor__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__truediv__',
#  '__trunc__',
#  '__xor__',
# ...

# %%
import random
dir(random)

# %%
type(random)
# Out:
# module

# %%
a= 5
b =3

print(a+b)
print(a-b)
print(a/b)
print(a//b) # (3*1 + 2)
print(a%b)
# Out:
# 8
# 2
# 1.6666666666666667
# 1
# 2

# %%
str1="hello"
str_methods=dir(str1)
type(str_methods)
# Out:
# list

# %%
s1= True
s2 = False
s3 = 0
s4 = 1

if s1:
  print("yes")
# Out:
# yes

# %%
if
